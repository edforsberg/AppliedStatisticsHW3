# %%
import numpy as np
from sklearn.metrics import accuracy_score

# %%
n = 500
sigma = [[1,0], [0,1]]

mu1 = [0,0]
mu2 = [1,1]

X1 = np.random.multivariate_normal(mu1, sigma, n)
X2 = np.random.multivariate_normal(mu2, sigma, n)

X_data = np.concatenate((X1, X2), axis=0)
y_data = np.concatenate((np.zeros(n), np.ones(n)), axis=0)

# %%
import sklearn.linear_model as lm

logistic_regression = lm.LogisticRegression(solver = 'liblinear', warm_start = True).fit(X_data, y_data)
lr_params = np.hstack((logistic_regression.intercept_[:,None], logistic_regression.coef_))[0]


y_pred = logistic_regression.predict(X_data)
accuracy = accuracy_score(y_data, y_pred)
error_rate_lr = 1 - accuracy
error_rate_lr
# Out:
# 0.246

# %%
##LDA 

import sklearn.discriminant_analysis as dm

linear_discriminant_analysis = dm.LinearDiscriminantAnalysis(solver = 'svd').fit(X_data, y_data) #'lsqr', 'eigen'

y_pred = linear_discriminant_analysis.predict(X_data)

accuracy = accuracy_score(y_data, y_pred,normalize=True)
error_rate_lda = 1 - accuracy
error_rate_lda
# Out:
# 0.243

# %%
a = linear_discriminant_analysis.get_params(deep=True)
a
x = np.arange(-5, 5, 0.1)
y = np.arange(-5, 5, 0.1)
xx, yy = np.meshgrid(x, y, sparse=True)
grid = np.array(float)

for i in xx:
    for j in yy:
        grid.append([i,j])

#h = plt.contourf(x,y,z)
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-389bd89ee1d6> in <module>
#       8 for i in xx:
#       9     for j in yy:
# ---> 10         grid.append([i,j])
#      11
#      12 #h = plt.contourf(x,y,z)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
def plot_decision_boundary(clf, X, Y, cmap='Paired_r'):
    h = 0.02
    x_min, x_max = X[:,0].min() - 10*h, X[:,0].max() + 10*h
    y_min, y_max = X[:,1].min() - 10*h, X[:,1].max() + 10*h
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.figure(figsize=(5,5))
    #plt.contourf(xx, yy, Z, cmap=cmap, alpha=0.25)
    plt.contour(xx, yy, Z, colors='k', linewidths=0.7)
    plt.scatter(X[:,0], X[:,1], c=Y, cmap=cmap, edgecolors='k');
    return Z
    
    
Z = plot_decision_boundary(linear_discriminant_analysis, X_data, y_data, cmap='Paired_r')
Z.shape
# Out:
# (417, 390)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8), dpi=80)
plt.scatter(X1[:,0], X1[:,1], s=20, color ='g', alpha=0.5)
plt.scatter(X2[:,0], X2[:,1], s=20, color = 'b', alpha=0.5)

db_x = [-2, 3]
db_y = [-(lr_params[0]+lr_params[1]*db_x[0])/lr_params[2], -(lr_params[0]+lr_params[1]*db_x[1])/lr_params[2]] 
plt.plot(db_x, db_y, marker = 'o')
plt.contour(xx, yy, Z, colors='k', linewidths=0.7)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-a83584509a4e> in <module>
#       8 db_y = [-(lr_params[0]+lr_params[1]*db_x[0])/lr_params[2], -(lr_params[0]+lr_params[1]*db_x[1])/lr_params[2]]
#       9 plt.plot(db_x, db_y, marker = 'o')
# ---> 10 plt.contour(xx, yy, Z, colors='k', linewidths=0.7)
#      11
#      12 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in contour(data, *args, **kwargs)
#    2535     __ret = gca().contour(
#    2536         *args, **({"data": data} if data is not None else {}),
# -> 2537         **kwargs)
#    2538     if __ret._A is not None: sci(__ret)  # noqa
#    2539     return __ret
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in contour(self, *args, **kwargs)
#    6229     def contour(self, *args, **kwargs):
#    6230         kwargs['filled'] = False
# -> 6231         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6232         self.autoscale_view()
#    6233         return contours
#
# ~\Anaconda3\lib\site-packages\matplotlib\contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     885         self._transform = kwargs.pop('transform', None)
#     886
# --> 887         kwargs = self._process_args(*args, **kwargs)
#     888         self._process_levels()
#     889
#
# ~\Anaconda3\lib\site-packages\matplotlib\contour.py in _process_args(self, *args, **kwargs)
#    1491                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1492
# -> 1493             x, y, z = self._contour_args(args, kwargs)
#    1494
#    1495             _mask = ma.getmask(z)
#
# ~\Anaconda3\lib\site-packages\matplotlib\contour.py in _contour_args(self, args, kwargs)
#    1549             args = args[1:]
#    1550         elif Nargs <= 4:
# -> 1551             x, y, z = self._check_xyz(args[:3], kwargs)
#    1552             args = args[3:]
#    1553         else:
#
# ~\Anaconda3\lib\site-packages\matplotlib\contour.py in _check_xyz(self, args, kwargs)
#    1609             if x.shape != z.shape:
#    1610                 raise TypeError("Shape of x does not match that of z: found "
# -> 1611                                 "{0} instead of {1}.".format(x.shape, z.shape))
#    1612
#    1613             if y.shape != z.shape:
#
# TypeError: Shape of x does not match that of z: found (1, 100) instead of (417, 390).
